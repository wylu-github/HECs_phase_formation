# %%
#main function

# %%
# %run code\parameters_calculation_1.ipynb
# %run code\descriptors_calculation_2.ipynb

# %%
parameters_calculation()#Empirical_phase_formation_rules_for_HECs

# %%
descriptors_calculation()#Calculations_of_ML_descriptors

# %%
# %run code\\SFS_3.ipynb
SFS()#SFS feature selection

# %%
# %run code\\accuracy_116_4.ipynb
allaccuracylist = accuracy_116()#Phase prediction of 116 HECs, return the accuracy of each algorithm
acclist = allaccuracylist[:6] 
acclist.append(allaccuracylist[-2])
acclist.append(allaccuracylist[-1])

# %%
# %run code\\prediction_382_5.ipynb

# %%
prediction_382()#Phase prediction of 382 HECs

# %%
# %run code\\DempsterShafer_116_6.ipynb

# %%
DempsterShafer_116(acclist)# DS of 116 HECs
# Out:
# D:\anacondainstall\envs\my_env\lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
# D:\anacondainstall\envs\my_env\lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %%
# %run code\\DempsterShafer_382_6.ipynb

# %%
DempsterShafer_382(acclist)# DS of 382 HECs
# Out:
# D:\anacondainstall\envs\my_env\lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
